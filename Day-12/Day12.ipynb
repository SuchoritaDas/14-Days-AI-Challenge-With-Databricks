# %%
import mlflow
import mlflow.sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Prepare data
# Minimal fix: create a DataFrame with two rows of sample data
import pandas as pd
sample_data = pd.DataFrame({"views": [1, 2], "cart_adds": [0, 1], "purchases": [0, 1]})
df = spark.createDataFrame(sample_data)
df = df.toPandas()
X = df[["views", "cart_adds"]]
y = df["purchases"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# MLflow experiment
with mlflow.start_run(run_name="linear_regression_v1"):
    # Log parameters
    mlflow.log_param("model_type", "LinearRegression")
    mlflow.log_param("test_size", 0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
score = model.score(X_test, y_test)
mlflow.log_metric("r2_score", score)
# Out:
# /databricks/python/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
# Log model
mlflow.sklearn.log_model(model, "model")
# Out:
# 2026/01/20 13:50:09 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
print(f"R² Score: {score:.4f}")
# Out:
# R² Score: nan
